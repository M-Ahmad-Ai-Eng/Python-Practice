# %% [markdown]
# # Day_41

# %% [markdown]
# ### Short Hand If Else
# - It is also a conditional statment but in a very simple and in very minimum form factor.
# - They are use when we onlt test the code or for short form of conditional statment which have not that much or data.

# %%
a = 1
b = 0
print("Max") if a>b else print("Min")

# %%
age = int(input("Enter your age : "))

print("Allowed") if age>18 else ("Not Allowed")

# %%
age = int(input("Enter your age : "))

"Child" if 0<age<=12  else("Boy" if 13<=age<=40  else("Man" if 41<=age<100 else "Older" ))

# if you notice I use the "" to print the stement rather then use the print() function so in short form of conditional stament we use the "" to print something.

# %% [markdown]
# ## Day_42

# %% [markdown]
# ### Enumerate
#
# - enumerate() function adds a counter to each item in a list or any other iterable, and returns a list of tuples containing the index position and the element for each element of the iterable.
# - It turns the iterable into something we can loop through using indexes, where each item comes with its number (starting from 0 by default).

# %%
marks = [15,23,24,12,21,25,28,21]

for i,mark in enumerate(marks): # here you see the i that work as a index that we want to calculate as far as the loop procced.
    print(mark)
    if i == 3:
        print("The lowest marks in the whole class.")

# %% [markdown]
# ## Day_43
#
# ### Virtual Environment
# - The tool which use to Isolate the specific python environments in a single machine.
# - Like they help to make the work on different projects with out any packages conflict and any problem.
# - We use many tools or commands to make the Virtual Envirnment but the best one and recommened is the uv which is the project and package manager for python.
# - You use any other tools but the uv is extremely fast and flexable and easy to setup.
# - The venv is the build in module use to create a virtual env for your project.
# - The uv the external one that you need to install by the **[powershell -ExecutionPolicy ByPass -c "irm https://astral.sh/uv/install.ps1 | iex"]** for windows.

# %% [markdown]
# ## Day_44

# %% [markdown]
# ## Import Module inPython
#
# - The import module help to load the code of the module into the current script to use it.
#
# #### To use Module
# ```
# import module_name
# ```
# - Here after the **import** you use the module name to import that module into your script.

# %%
from math import pi,sqrt,sin# by this way you only import the specific functions from the module not the whole module.

print(pi)# print the value of the pi.
print(sin(90))# print the sin teta of the 90 degree.
print(sqrt(81))# print the square root of the number(81).
print(math.cos(20)) # you see this line are not working and cause error because the math are not defined we use the pi,... and other instead of the math whole module functions.

# %%
import math as mt # here you use the any word instead of the mt to easly import the math by the help of that mt.

num = int(input("Enter your Number : "))
print(f"The Square Root of the {num} is :",mt.sqrt(num))# Give the Square root of the number

# %%
from math import * # this is not the recommended method because you can face a lot of problem a lot of problems at that way you are confuse what ever that the pi is a variable or a function
# and some time we use a multiple module inside our project and we face a serius issue because at that situatuin we use the module names as alis form like pandas as pd and we use pd.read_csv()


print(cos(0),cos(90),cos(180),cos(360))
print(sin(0),sin(80),sin(180),sin(360))
print(tan(0),tan(90),tan(180),tan(360))

# %%
import math as m

print(dir(m))# the dir help to write the whole functions name inside the module.
# in Python dir() is a built-in tool that returns a list of valid attributes and methods for an object or the current scope

# %%
from import_file import square# we also import our python modules or files and use it through the import function

print(square.square(5))# we import the square function from te import_file

# %% [markdown]
# ## Day_45
#
# **if __ name __ == "__ main __"**
#
# - This help us to clearify from wheater the file is imprted is the file itself is imported or by other module or script call it.
# - If we add this **if __ name __ == "__ main __"** in a file that we don't want to execute when we import into other scripts or program.
#
# **for more detailed you see the day_45.py to get a proper undersatanding**
